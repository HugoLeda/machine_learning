# %% [markdown]
# <a href="https://colab.research.google.com/github/HugoLeda/machine_learning/blob/main/Feature%20importance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import load_iris

# Carregar os dados
data = load_iris()
X, y = data.data, data.target

# Treinar o modelo
model = RandomForestClassifier()
model.fit(X, y)

# Importância das features
importances = model.feature_importances_

plt.figure(figsize=(4, 4))
plt.pie(importances, labels=data.feature_names, autopct='%1.1f%%', startangle=120)
plt.title('Importância das Features')
plt.axis('equal')
plt.show()
